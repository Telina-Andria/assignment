# %% [markdown]
# ## Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# Matplotlib is a librarie in Python that it is used to plot graph so you can gain more information about your data. It provides a wide range of tools for creating different types of visualizations, such as line charts, scatter plots, bar charts, histograms, box plot,and more. By using Matplotlib, you can gain insights into your data and communicate your findings effectively.

# %% [markdown]
# ## Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(3)

x = 3 + np.random.normal(0, 2, 50)

y = 3 + np.random.normal(0, 2, len(x))

# Note: Also add title, xlabel, and ylabel to the plot

# %%
plt.scatter(x, y, c = "r")
plt.xlabel("X axis")
plt.ylabel("y label")
plt.title("Scatter plot graph")
plt.show()

# %% [markdown]
# ## Q3. Why is the subplot() function used? Draw four line plots using the subplot() function

# %% [markdown]
# Use the following data:
#
# import numpy as np
#
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and  y = np.array([0, 100, 200, 300, 400, 500])
#
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# The subplot() function in Matplotlib is used to create multiple plots in a single figure. It takes three arguments: the number of rows, the number of columns, and the index of the subplot. By specifying the index of each subplot, you can arrange them in a grid-like structure. This is useful when you want to compare different plots side by side or when you want to show different aspects of the same data in separate plots.

# %%
# Define the data for each line
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2)

# Plot each line on a separate subplot
axs[0, 0].plot(x1, y1)
axs[0, 1].plot(x2, y2)
axs[1, 0].plot(x3, y3)
axs[1, 1].plot(x4, y4)

# Add titles to each subplot
axs[0, 0].set_title('Line 1')
axs[0, 1].set_title('Line 2')
axs[1, 0].set_title('Line 3')
axs[1, 1].set_title('Line 4')

# Add a main title to the figure
fig.suptitle('Four Line Plots')

# Display the figure
plt.show()

# %% [markdown]
# ## Q4. What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [markdown]
# A bar plot is a type of chart that represents data using rectangular bars. The length or height of each bar corresponds to the value of the data it represents. Bar plots are commonly used to compare the values of different categories or groups of data.
#
# Bar plots are useful when you want to visualize the distribution or frequency of categorical data. They can also be used to compare the relative sizes of different groups or categories.

# %%
import numpy as np

company = np.array(["Apple", "Microsoft", "Google", "AMD"])

profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company, profit)
plt.show()

# %%
plt.barh(company, profit)
plt.show()

# %% [markdown]
# ## Q5. What is a box plot? Why is it used? Using the following data plot a box plot

# %% [markdown]
# A box plot is a type of chart that displays the distribution of a dataset. It shows the median, quartiles, and outliers of the data in a compact and easy-to-read format.

# %%
box1 = np.random.normal(100, 10, 200)

box2 = np.random.normal(90, 20, 200)

# %%
plt.boxplot(box1)
plt.show()

# %%
plt.boxplot(box2)
plt.show()
